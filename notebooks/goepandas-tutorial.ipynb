# %%
import geopandas as gpd

# %%
gdf_bikelane = gpd.read_file('../data/raw/bikelane-infra.json')

# %%
gdf_bikelane.head()
# Out:
#    ID_CYCL  ID_TRC AFFICHEUR_DYNAMIQUE AVANCEMENT_CODE  \
# 0    27156       0                 Non               E
# 1    26855       0                 Non               E
# 2    27798       0                 Non               E
# 3    27939       0                 Non               E
# 4    28528       0                 Non               E
#
#            AVANCEMENT_DESC COMPTEUR_CYLISTE  LONGUEUR  NBR_VOIE  \
# 0  Voie cyclable existante              Non       142         2
# 1  Voie cyclable existante              Non       295         2
# 2  Voie cyclable existante              Non       701         2
# 3  Voie cyclable existante              Non       269         2
# 4  Voie cyclable existante              Non        91         2
#
#   NOM_ARR_VILLE_CODE                    NOM_ARR_VILLE_DESC  ... SAISONS4  \
# 0                 VM                           Ville-Marie  ...      Non
# 1                 LR                         Saint-Laurent  ...      Non
# ...

# %%
type(gdf_bikelane)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
gdf_bikelane.head(1)
# Out:
#    ID_CYCL  ID_TRC AFFICHEUR_DYNAMIQUE AVANCEMENT_CODE  \
# 0    27156       0                 Non               E
#
#            AVANCEMENT_DESC COMPTEUR_CYLISTE  LONGUEUR  NBR_VOIE  \
# 0  Voie cyclable existante              Non       142         2
#
#   NOM_ARR_VILLE_CODE NOM_ARR_VILLE_DESC  ... SAISONS4 SAS_VELO  \
# 0                 VM        Ville-Marie  ...      Non      Non
#
#   SEPARATEUR_CODE SEPARATEUR_DESC TYPE_VOIE_CODE  \
# 0            None            None              5
#
#                   TYPE_VOIE_DESC TYPE_VOIE2_CODE  \
# 0  Piste cyclable en site propre               1
#
#                                TYPE_VOIE2_DESC VILLE_MTL  \
# 0  Par défaut - Dans le sens de la circulation       Oui
#
#                                             geometry
# 0  LINESTRING (-73.55209 45.49279, -73.55212 45.4...
#
# [1 rows x 24 columns]

# %%
gdf_bikelane['geometry'][0]
# Out:
# <LINESTRING (-73.552 45.493, -73.552 45.493, -73.552 45.493, -73.552 45.493,...>

# %%
gdf_bikelane.plot()
# Out:
# <Axes: >

# %%
gdf_boroughs = gpd.read_file('../data/raw/borough-shapes.json')

# %%
gdf_boroughs['geometry'][0]
# Out:
# <MULTIPOLYGON (((-73.666 45.422, -73.665 45.422, -73.664 45.421, -73.655 45....>
